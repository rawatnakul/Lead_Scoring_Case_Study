# %% [markdown]
# # Step-1: Reading and Understanding data

# %%
import warnings
warnings.filterwarnings ('ignore')

# %%
# importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# reading the database
lead_data = pd.read_csv('Leads.csv')
lead_data.head()
# Out:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      API
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
#
#       Lead Source Do Not Email Do Not Call  Converted  TotalVisits  \
# 0      Olark Chat           No          No          0          0.0
# 1  Organic Search           No          No          0          5.0
# 2  Direct Traffic           No          No          1          2.0
# 3  Direct Traffic           No          No          0          1.0
# 4          Google           No          No          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit  ...  \
# ...

# %%
# Checking the number of rows and columns in the dataset
lead_data.shape
# Out:
# (9240, 37)

# %%
lead_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9240 entries, 0 to 9239
# Data columns (total 37 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Prospect ID                                    9240 non-null   object
#  1   Lead Number                                    9240 non-null   int64
#  2   Lead Origin                                    9240 non-null   object
#  3   Lead Source                                    9204 non-null   object
#  4   Do Not Email                                   9240 non-null   object
#  5   Do Not Call                                    9240 non-null   object
#  6   Converted                                      9240 non-null   int64
#  7   TotalVisits                                    9103 non-null   float64
#  8   Total Time Spent on Website                    9240 non-null   int64
# ...

# %%
lead_data.describe()
# Out:
#          Lead Number    Converted  TotalVisits  Total Time Spent on Website  \
# count    9240.000000  9240.000000  9103.000000                  9240.000000
# mean   617188.435606     0.385390     3.445238                   487.698268
# std     23405.995698     0.486714     4.854853                   548.021466
# min    579533.000000     0.000000     0.000000                     0.000000
# 25%    596484.500000     0.000000     1.000000                    12.000000
# 50%    615479.000000     0.000000     3.000000                   248.000000
# 75%    637387.250000     1.000000     5.000000                   936.000000
# max    660737.000000     1.000000   251.000000                  2272.000000
#
#        Page Views Per Visit  Asymmetrique Activity Score  \
# count           9103.000000                  5022.000000
# mean               2.362820                    14.306252
# std                2.161418                     1.386694
# ...

# %%
# determining the total number of null values in each column
lead_data.isna().sum()
# Out:
# Prospect ID                                         0
# Lead Number                                         0
# Lead Origin                                         0
# Lead Source                                        36
# Do Not Email                                        0
# Do Not Call                                         0
# Converted                                           0
# TotalVisits                                       137
# Total Time Spent on Website                         0
# Page Views Per Visit                              137
# Last Activity                                     103
# Country                                          2461
# Specialization                                   1438
# How did you hear about X Education               2207
# What is your current occupation                  2690
# What matters most to you in choosing a course    2709
# Search                                              0
# ...

# %%
# determining the percentage of the null values in each column
lead_data.isna().sum()/len(lead_data)*100
# Out:
# Prospect ID                                       0.000000
# Lead Number                                       0.000000
# Lead Origin                                       0.000000
# Lead Source                                       0.389610
# Do Not Email                                      0.000000
# Do Not Call                                       0.000000
# Converted                                         0.000000
# TotalVisits                                       1.482684
# Total Time Spent on Website                       0.000000
# Page Views Per Visit                              1.482684
# Last Activity                                     1.114719
# Country                                          26.634199
# Specialization                                   15.562771
# How did you hear about X Education               23.885281
# What is your current occupation                  29.112554
# What matters most to you in choosing a course    29.318182
# ...

# %% [markdown]
# # Step-2 Data Preprocessing

# %%
# list of columns having null value greater than 40%
cols = []
for values in lead_data.columns:
    if lead_data[values].isna().mean() * 100 >40:
        cols.append(values)
print(cols)
# Out:
# ['Lead Quality', 'Asymmetrique Activity Index', 'Asymmetrique Profile Index', 'Asymmetrique Activity Score', 'Asymmetrique Profile Score']

# %%
lead_data.drop(cols, axis=1, inplace=True)
lead_data.head()
# Out:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      API
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
#
#       Lead Source Do Not Email Do Not Call  Converted  TotalVisits  \
# 0      Olark Chat           No          No          0          0.0
# 1  Organic Search           No          No          0          5.0
# 2  Direct Traffic           No          No          1          2.0
# 3  Direct Traffic           No          No          0          1.0
# 4          Google           No          No          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit  ...  \
# ...

# %%
lead_data.isna().sum()
# Out:
# Prospect ID                                         0
# Lead Number                                         0
# Lead Origin                                         0
# Lead Source                                        36
# Do Not Email                                        0
# Do Not Call                                         0
# Converted                                           0
# TotalVisits                                       137
# Total Time Spent on Website                         0
# Page Views Per Visit                              137
# Last Activity                                     103
# Country                                          2461
# Specialization                                   1438
# How did you hear about X Education               2207
# What is your current occupation                  2690
# What matters most to you in choosing a course    2709
# Search                                              0
# ...

# %%
lead_data.drop('Tags', axis = 1, inplace = True)

# %%
lead_data.isna().sum()
# Out:
# Prospect ID                                         0
# Lead Number                                         0
# Lead Origin                                         0
# Lead Source                                        36
# Do Not Email                                        0
# Do Not Call                                         0
# Converted                                           0
# TotalVisits                                       137
# Total Time Spent on Website                         0
# Page Views Per Visit                              137
# Last Activity                                     103
# Country                                          2461
# Specialization                                   1438
# How did you hear about X Education               2207
# What is your current occupation                  2690
# What matters most to you in choosing a course    2709
# Search                                              0
# ...

# %%
# checking values in country
lead_data.Country.value_counts()
# Out:
# Country
# India                   6492
# United States             69
# United Arab Emirates      53
# Singapore                 24
# Saudi Arabia              21
# United Kingdom            15
# Australia                 13
# Qatar                     10
# Hong Kong                  7
# Bahrain                    7
# Oman                       6
# France                     6
# unknown                    5
# South Africa               4
# Nigeria                    4
# Germany                    4
# Kuwait                     4
# Canada                     4
# Sweden                     3
# China                      2
# Asia/Pacific Region        2
# Uganda                     2
# Bangladesh                 2
# Italy                      2
# Belgium                    2
# Netherlands                2
# Ghana                      2
# Philippines                2
# Russia                     1
# Switzerland                1
# Vietnam                    1
# ...

# %% [markdown]
# #### It can be seen that India has highest number of leads.

# %%
# dropping the country column
lead_data.drop('Country', axis =1, inplace = True)

# %%
# checking for value count in City
lead_data.City.value_counts()
# Out:
# City
# Mumbai                         3222
# Select                         2249
# Thane & Outskirts               752
# Other Cities                    686
# Other Cities of Maharashtra     457
# Other Metro Cities              380
# Tier II Cities                   74
# Name: count, dtype: int64

# %% [markdown]
# #### most of the leads are from mumbai

# %%
lead_data.drop('City', axis = 1, inplace = True)

# %%
lead_data.isna().sum()
# Out:
# Prospect ID                                         0
# Lead Number                                         0
# Lead Origin                                         0
# Lead Source                                        36
# Do Not Email                                        0
# Do Not Call                                         0
# Converted                                           0
# TotalVisits                                       137
# Total Time Spent on Website                         0
# Page Views Per Visit                              137
# Last Activity                                     103
# Specialization                                   1438
# How did you hear about X Education               2207
# What is your current occupation                  2690
# What matters most to you in choosing a course    2709
# Search                                              0
# Magazine                                            0
# ...

# %% [markdown]
# #### It can be observed from the given data that specialization, Lead Profile, and How did you hear about X education have select values

# %%
lead_data.Specialization.value_counts()
# Out:
# Specialization
# Select                               1942
# Finance Management                    976
# Human Resource Management             848
# Marketing Management                  838
# Operations Management                 503
# Business Administration               403
# IT Projects Management                366
# Supply Chain Management               349
# Banking, Investment And Insurance     338
# Travel and Tourism                    203
# Media and Advertising                 203
# International Business                178
# Healthcare Management                 159
# Hospitality Management                114
# E-COMMERCE                            112
# Retail Management                     100
# Rural and Agribusiness                 73
# E-Business                             57
# Services Excellence                    40
# Name: count, dtype: int64

# %%
lead_data['Lead Profile'].value_counts()
# Out:
# Lead Profile
# Select                         4146
# Potential Lead                 1613
# Other Leads                     487
# Student of SomeSchool           241
# Lateral Student                  24
# Dual Specialization Student      20
# Name: count, dtype: int64

# %%
lead_data['How did you hear about X Education'].value_counts()
# Out:
# How did you hear about X Education
# Select                   5043
# Online Search             808
# Word Of Mouth             348
# Student of SomeSchool     310
# Other                     186
# Multiple Sources          152
# Advertisements             70
# Social Media               67
# Email                      26
# SMS                        23
# Name: count, dtype: int64

# %%
lead_data.drop(['How did you hear about X Education', 'Lead Profile'], axis =1, inplace = True)

# %%
lead_data.isna().sum()
# Out:
# Prospect ID                                         0
# Lead Number                                         0
# Lead Origin                                         0
# Lead Source                                        36
# Do Not Email                                        0
# Do Not Call                                         0
# Converted                                           0
# TotalVisits                                       137
# Total Time Spent on Website                         0
# Page Views Per Visit                              137
# Last Activity                                     103
# Specialization                                   1438
# What is your current occupation                  2690
# What matters most to you in choosing a course    2709
# Search                                              0
# Magazine                                            0
# Newspaper Article                                   0
# ...

# %%
lead_data = lead_data.dropna()

# %%
lead_data.isna().sum()
# Out:
# Lead Origin                                      0
# Lead Source                                      0
# Do Not Email                                     0
# Do Not Call                                      0
# Converted                                        0
# TotalVisits                                      0
# Total Time Spent on Website                      0
# Page Views Per Visit                             0
# Last Activity                                    0
# Country                                          0
# Specialization                                   0
# How did you hear about X Education               0
# What is your current occupation                  0
# What matters most to you in choosing a course    0
# Search                                           0
# Magazine                                         0
# Newspaper Article                                0
# X Education Forums                               0
# ...

# %%
lead_data.drop(['Do Not Call', 'Search', 'Magazine', 'Newspaper Article', 'X Education Forums', 'Newspaper', 
            'Digital Advertisement', 'Through Recommendations', 'Receive More Updates About Our Courses', 
            'Update me on Supply Chain Content', 'Get updates on DM Content', 
            'I agree to pay the amount through cheque'], axis = 1, inplace = True)

# %%
# checking values in what matters most to you in choosing a course
lead_data['What matters most to you in choosing a course'].value_counts()
# Out:
# What matters most to you in choosing a course
# Better Career Prospects      6528
# Flexibility & Convenience       2
# Other                           1
# Name: count, dtype: int64

# %%
lead_data.drop(['What matters most to you in choosing a course'], axis = 1, inplace=True)

# %%
lead_data = lead_data[~pd.isnull(lead_data['What is your current occupation'])]

# %% [markdown]
# ## Step-3 Data Visualisation

# %% [markdown]
# #### Univariate analysis

# %%
# Checking the distribution of lead source
sns.countplot(x = 'Lead Source', data = lead_data)
plt.xticks(rotation = 90)
plt.show()

# %%
# identifying the background of the people checking the course
sns.countplot(x = 'Specialization', data = lead_data)
plt.yticks(np.arange(0,3500,200))
plt.xticks(rotation = 90)
plt.show()

# %%
# Identifying the pattern of converted and non-converted individuals using different parameters
sns.pairplot(lead_data,diag_kind='kde',hue='Converted')
plt.show()

# %%
lead_data.head()
# Out:
#                Lead Origin     Lead Source Do Not Email Do Not Call  \
# 0                      API      Olark Chat           No          No
# 1                      API  Organic Search           No          No
# 2  Landing Page Submission  Direct Traffic           No          No
# 3  Landing Page Submission  Direct Traffic           No          No
# 4  Landing Page Submission          Google           No          No
#
#    Converted  TotalVisits  Total Time Spent on Website  Page Views Per Visit  \
# 0          0          0.0                            0                   0.0
# 1          0          5.0                          674                   2.5
# 2          1          2.0                         1532                   2.0
# 3          0          1.0                          305                   1.0
# 4          1          2.0                         1428                   1.0
#
#              Last Activity  Country  ...                                 Tags  \
# ...

# %% [markdown]
# ### Bivariate analysis

# %%
# checking for origion of leads using converted as hue
sns.countplot(x = 'Lead Origin', hue = 'Converted', data = lead_data)
plt.xticks(rotation = 90)
plt.show()

# %%
sns.countplot(x = 'Lead Source', hue = 'Converted', data = lead_data)
plt.xticks(rotation = 90)
plt.show()

# %%
# comparing the professions of all leads, converted and non-converted
sns.countplot(x = 'Specialization', hue = 'Converted', data = lead_data)
plt.xticks(rotation = 90)
plt.show()

# %%
# determining what is the occupation of converted leads
sns.countplot(x = 'What is your current occupation', hue = 'Converted', data = lead_data)
plt.xticks(rotation = 90)
plt.show()

# %%
# comparing the total visits of leads on website
sns.countplot(data=lead_data, hue='Converted', x="TotalVisits")
plt.xticks(rotation = 90)
plt.show()

# %%
# comparison of time spent on website between converted and non-converted leads
sns.boxplot(data=lead_data, x="Converted", y="Total Time Spent on Website")
plt.show()

# %%
sns.boxplot(data=lead_data, x="Converted", y="Page Views Per Visit")
plt.ylim(0,20)
plt.show()

# %%
# checking for categorical columns
cat_cols = lead_data.loc[:, lead_data.dtypes == 'object']
cat_cols.columns
# Out:
# Index(['Prospect ID', 'Lead Origin', 'Lead Source', 'Do Not Email',
#        'Last Activity', 'Specialization', 'What is your current occupation',
#        'A free copy of Mastering The Interview', 'Last Notable Activity'],
#       dtype='object')

# %%
# dropping the rows with null values in lead source
lead_data = lead_data[~pd.isnull(lead_data['Lead Source'])]

# %%
# dropping the rows with bull values in Total visits
lead_data = lead_data[~pd.isnull(lead_data['TotalVisits'])]

# %%
lead_data.isna().sum()
# Out:
# Prospect ID                                0
# Lead Number                                0
# Lead Origin                                0
# Lead Source                                0
# Do Not Email                               0
# Converted                                  0
# TotalVisits                                0
# Total Time Spent on Website                0
# Page Views Per Visit                       0
# Last Activity                              0
# Specialization                            18
# What is your current occupation            0
# A free copy of Mastering The Interview     0
# Last Notable Activity                      0
# dtype: int64

# %%
# dropping the rows with null values in Specialization
lead_data = lead_data[~pd.isnull(lead_data['Specialization'])]

# %%
lead_data.isna().sum()
# Out:
# Prospect ID                               0
# Lead Number                               0
# Lead Origin                               0
# Lead Source                               0
# Do Not Email                              0
# Converted                                 0
# TotalVisits                               0
# Total Time Spent on Website               0
# Page Views Per Visit                      0
# Last Activity                             0
# Specialization                            0
# What is your current occupation           0
# A free copy of Mastering The Interview    0
# Last Notable Activity                     0
# dtype: int64

# %%
lead_data.drop(['Prospect ID', 'Lead Number'], axis =1, inplace = True)

# %%
lead_data.head()
# Out:
#                Lead Origin     Lead Source Do Not Email  Converted  \
# 0                      API      Olark Chat           No          0
# 1                      API  Organic Search           No          0
# 2  Landing Page Submission  Direct Traffic           No          1
# 3  Landing Page Submission  Direct Traffic           No          0
# 4  Landing Page Submission          Google           No          1
#
#    TotalVisits  Total Time Spent on Website  Page Views Per Visit  \
# 0          0.0                            0                   0.0
# 1          5.0                          674                   2.5
# 2          2.0                         1532                   2.0
# 3          1.0                          305                   1.0
# 4          2.0                         1428                   1.0
#
#              Last Activity           Specialization  \
# 0  Page Visited on Website                   Select
# 1             Email Opened                   Select
# ...

# %%
cat_cols = lead_data.loc[:, lead_data.dtypes == 'object']
cat_cols.columns
# Out:
# Index(['Lead Origin', 'Lead Source', 'Do Not Email', 'Last Activity',
#        'Specialization', 'What is your current occupation',
#        'A free copy of Mastering The Interview', 'Last Notable Activity'],
#       dtype='object')

# %% [markdown]
# ## Getting dummy variables

# %%
dummy = pd.get_dummies(lead_data[['Lead Origin', 'Lead Source', 'Do Not Email', 'Last Activity',
       'Specialization', 'What is your current occupation',
       'A free copy of Mastering The Interview', 'Last Notable Activity']], dtype = int, drop_first=True)

# Add the results to the master dataframe
lead_data = pd.concat([lead_data, dummy], axis=1)

# %%
lead_data = lead_data.drop(['Lead Origin', 'Lead Source', 'Do Not Email', 'Last Activity',
       'Specialization', 'What is your current occupation',
       'A free copy of Mastering The Interview', 'Last Notable Activity'], axis = 1)

# %%
lead_data.head()
# Out:
#    Converted  TotalVisits  Total Time Spent on Website  Page Views Per Visit  \
# 0          0          0.0                            0                   0.0
# 1          0          5.0                          674                   2.5
# 2          1          2.0                         1532                   2.0
# 3          0          1.0                          305                   1.0
# 4          1          2.0                         1428                   1.0
#
#    Lead Origin_Landing Page Submission  Lead Origin_Lead Add Form  \
# 0                                    0                          0
# 1                                    0                          0
# 2                                    1                          0
# 3                                    1                          0
# 4                                    1                          0
#
#    Lead Origin_Lead Import  Lead Source_Direct Traffic  Lead Source_Facebook  \
# ...

# %% [markdown]
# ## Splitting the data

# %%
from sklearn.model_selection import train_test_split

# %%
X = lead_data.drop(['Converted'], axis =1)
X.head()
# Out:
#    TotalVisits  Total Time Spent on Website  Page Views Per Visit  \
# 0          0.0                            0                   0.0
# 1          5.0                          674                   2.5
# 2          2.0                         1532                   2.0
# 3          1.0                          305                   1.0
# 4          2.0                         1428                   1.0
#
#    Lead Origin_Landing Page Submission  Lead Origin_Lead Add Form  \
# 0                                    0                          0
# 1                                    0                          0
# 2                                    1                          0
# 3                                    1                          0
# 4                                    1                          0
#
#    Lead Origin_Lead Import  Lead Source_Direct Traffic  Lead Source_Facebook  \
# 0                        0                           0                     0
# ...

# %%
y = lead_data['Converted']

y.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Converted, dtype: int64

# %%
#splitting in training and test
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, test_size=0.3, random_state=100)

# %% [markdown]
# #### Scaling the variables

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
X_train[['TotalVisits', 'Page Views Per Visit', 'Total Time Spent on Website']] = scaler.fit_transform(X_train[['TotalVisits', 'Page Views Per Visit', 'Total Time Spent on Website']])
X_train.head()
# Out:
#       TotalVisits  Total Time Spent on Website  Page Views Per Visit  \
# 8003     0.015936                     0.029489                 0.125
# 218      0.015936                     0.082306                 0.250
# 4171     0.023904                     0.034331                 0.375
# 4037     0.000000                     0.000000                 0.000
# 3660     0.000000                     0.000000                 0.000
#
#       Lead Origin_Landing Page Submission  Lead Origin_Lead Add Form  \
# 8003                                    1                          0
# 218                                     1                          0
# 4171                                    1                          0
# 4037                                    0                          0
# 3660                                    0                          1
#
#       Lead Origin_Lead Import  Lead Source_Direct Traffic  \
# 8003                        0                           1
# ...

# %% [markdown]
# # Step-4: Model Building

# %%
# importing logistic regression
from sklearn.linear_model import LogisticRegression
regressor = LogisticRegression()

# %%
# importing RFE
from sklearn.feature_selection import RFE
rfe = RFE(regressor, n_features_to_select=15)
rfe = rfe.fit(X_train, y_train)

# %%
list(zip(X_train.columns, rfe.support_, rfe.ranking_))
# Out:
# [('TotalVisits', True, 1),
#  ('Total Time Spent on Website', True, 1),
#  ('Page Views Per Visit', False, 11),
#  ('Lead Origin_Landing Page Submission', False, 2),
#  ('Lead Origin_Lead Add Form', True, 1),
#  ('Lead Origin_Lead Import', False, 50),
#  ('Lead Source_Direct Traffic', False, 15),
#  ('Lead Source_Facebook', False, 40),
#  ('Lead Source_Google', False, 33),
#  ('Lead Source_Live Chat', False, 35),
#  ('Lead Source_Olark Chat', True, 1),
#  ('Lead Source_Organic Search', False, 32),
#  ('Lead Source_Pay per Click Ads', False, 31),
#  ('Lead Source_Press_Release', False, 54),
#  ('Lead Source_Reference', False, 4),
#  ('Lead Source_Referral Sites', False, 34),
#  ('Lead Source_Social Media', False, 60),
#  ('Lead Source_WeLearn', False, 24),
#  ('Lead Source_Welingak Website', True, 1),
#  ('Lead Source_bing', False, 20),
#  ('Lead Source_testone', False, 30),
#  ('Do Not Email_Yes', True, 1),
#  ('Last Activity_Converted to Lead', False, 12),
# ...

# %%
col = X_train.columns[rfe.support_]

# %%
X_train = X_train[col]

# %%
import statsmodels.api as sm

# %%
# making model
X_train_sm = sm.add_constant(X_train)
logm2 = sm.GLM(y_train, X_train_sm, family = sm.families.Binomial())
res = logm2.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:              Converted   No. Observations:                 4461
# Model:                            GLM   Df Residuals:                     4445
# Model Family:                Binomial   Df Model:                           15
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2067.2
# Date:                Mon, 26 Aug 2024   Deviance:                       4134.4
# Time:                        13:00:49   Pearson chi2:                 4.83e+03
# No. Iterations:                    22   Pseudo R-squ. (CS):             0.3676
# Covariance Type:            nonrobust
# ...
#                                                            coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %% [markdown]
# ## checking for multicollineraity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# calculating VIF
vif = pd.DataFrame()
vif['Features'] = X_train.columns
vif['VIF'] = [variance_inflation_factor(X_train.values, i) for i in range(X_train.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                                              Features   VIF
# 11         What is your current occupation_Unemployed  4.13
# 6              Last Activity_Had a Phone Conversation  2.44
# 13     Last Notable Activity_Had a Phone Conversation  2.43
# 1                         Total Time Spent on Website  2.39
# 8                               Specialization_Select  1.90
# 2                           Lead Origin_Lead Add Form  1.71
# 3                              Lead Source_Olark Chat  1.66
# 0                                         TotalVisits  1.63
# 7                              Last Activity_SMS Sent  1.59
# 12  What is your current occupation_Working Profes...  1.56
# 4                        Lead Source_Welingak Website  1.37
# 10            What is your current occupation_Student  1.10
# 5                                    Do Not Email_Yes  1.09
# 9           What is your current occupation_Housewife  1.01
# 14                  Last Notable Activity_Unreachable  1.01

# %% [markdown]
# #### All the variables have VIF less then 5, so dropping the variables with high p value.

# %%
X_train.drop('Last Notable Activity_Had a Phone Conversation', axis = 1, inplace = True)

# %%
logm1 = sm.GLM(y_train,(sm.add_constant(X_train)), family = sm.families.Binomial())
logm1.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:              Converted   No. Observations:                 4461
# Model:                            GLM   Df Residuals:                     4446
# Model Family:                Binomial   Df Model:                           14
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2069.8
# Date:                Mon, 26 Aug 2024   Deviance:                       4139.6
# Time:                        13:04:42   Pearson chi2:                 4.84e+03
# No. Iterations:                    21   Pseudo R-squ. (CS):             0.3668
# Covariance Type:            nonrobust
# ...
#                                                            coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %%
X_train.drop('What is your current occupation_Housewife', axis = 1, inplace = True)

# %%
logm1 = sm.GLM(y_train,(sm.add_constant(X_train)), family = sm.families.Binomial())
logm1.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:              Converted   No. Observations:                 4461
# Model:                            GLM   Df Residuals:                     4447
# Model Family:                Binomial   Df Model:                           13
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2072.0
# Date:                Mon, 26 Aug 2024   Deviance:                       4143.9
# Time:                        13:06:32   Pearson chi2:                 4.84e+03
# No. Iterations:                     7   Pseudo R-squ. (CS):             0.3662
# Covariance Type:            nonrobust
# ...
#                                                            coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %%
X_train.drop('What is your current occupation_Working Professional', axis = 1, inplace = True)

# %%
logm1 = sm.GLM(y_train,(sm.add_constant(X_train)), family = sm.families.Binomial())
res = logm1.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:              Converted   No. Observations:                 4461
# Model:                            GLM   Df Residuals:                     4448
# Model Family:                Binomial   Df Model:                           12
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2072.6
# Date:                Mon, 26 Aug 2024   Deviance:                       4145.3
# Time:                        13:07:53   Pearson chi2:                 4.81e+03
# No. Iterations:                     7   Pseudo R-squ. (CS):             0.3660
# Covariance Type:            nonrobust
# ...
#                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %%
logm1 = sm.GLM(y_train,(sm.add_constant(X_train)), family = sm.families.Binomial())
res = logm1.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:              Converted   No. Observations:                 6351
# Model:                            GLM   Df Residuals:                     6336
# Model Family:                Binomial   Df Model:                           14
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -1246.4
# Date:                Thu, 22 Aug 2024   Deviance:                       2492.8
# Time:                        22:14:04   Pearson chi2:                 7.67e+03
# No. Iterations:                    23   Pseudo R-squ. (CS):             0.6096
# Covariance Type:            nonrobust
# ...
#                                                             coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %%
vif = pd.DataFrame()
vif['Features'] = X_train.columns
vif['VIF'] = [variance_inflation_factor(X_train.values, i) for i in range(X_train.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                                       Features   VIF
# 10  What is your current occupation_Unemployed  3.25
# 1                  Total Time Spent on Website  2.01
# 8                        Specialization_Select  1.90
# 3                       Lead Source_Olark Chat  1.56
# 0                                  TotalVisits  1.55
# 7                       Last Activity_SMS Sent  1.51
# 2                    Lead Origin_Lead Add Form  1.46
# 4                 Lead Source_Welingak Website  1.34
# 5                             Do Not Email_Yes  1.08
# 9      What is your current occupation_Student  1.08
# 6       Last Activity_Had a Phone Conversation  1.01
# 11           Last Notable Activity_Unreachable  1.01

# %% [markdown]
# # Step-5 Model Evaluation

# %%
# making predictions on the y_train
y_train_pred = res.predict(sm.add_constant(X_train))
y_train_pred[:10]
# Out:
# 8003    0.317060
# 218     0.152306
# 4171    0.136140
# 4037    0.277702
# 3660    0.959984
# 207     0.155001
# 2044    0.143021
# 6411    0.949236
# 6498    0.080049
# 2085    0.981888
# dtype: float64

# %%
y_train_pred = y_train_pred.values.reshape(-1)
y_train_pred[:10]
# Out:
# array([0.31706043, 0.15230642, 0.13613956, 0.27770195, 0.95998364,
#        0.1550006 , 0.14302095, 0.94923559, 0.08004927, 0.98188829])

# %%
y_train_pred_final = pd.DataFrame({'Converted':y_train.values, 'Conversion_Prob':y_train_pred})
y_train_pred_final.head()
# Out:
#    Converted  Conversion_Prob
# 0          0         0.317060
# 1          0         0.152306
# 2          1         0.136140
# 3          1         0.277702
# 4          1         0.959984

# %%
y_train_pred_final['Predicted'] = y_train_pred_final.Conversion_Prob.map(lambda x: 1 if x > 0.5 else 0)

y_train_pred_final.head()
# Out:
#    Converted  Conversion_Prob  Predicted
# 0          0         0.317060          0
# 1          0         0.152306          0
# 2          1         0.136140          0
# 3          1         0.277702          0
# 4          1         0.959984          1

# %%
from sklearn import metrics

# %%
#creating confusion matrix
matrix = metrics.confusion_matrix(y_train_pred_final.Converted, y_train_pred_final.Predicted )
print(matrix)
# Out:
# [[1925  387]
#  [ 562 1587]]

# %%
# checking accuracy
print(metrics.accuracy_score(y_train_pred_final.Converted, y_train_pred_final.Predicted))
# Out:
# 0.7872674288276171

# %%
# describing confusion metrics
TP = matrix[1,1] 
TN = matrix[0,0]
FP = matrix[0,1]
FN = matrix[1,0]

# %%
# Specificity
TN/(TN+FP)
# Out:
# 0.8326124567474048

# %%
# Sensitivity
TP/(TP+FN)
# Out:
# 0.7384830153559795

# %%
def draw_roc( actual, probs ):
    fpr, tpr, thresholds = metrics.roc_curve( actual, probs,
                                              drop_intermediate = False )
    auc_score = metrics.roc_auc_score( actual, probs )
    plt.figure(figsize=(5, 5))
    plt.plot( fpr, tpr, label='ROC curve (area = %0.2f)' % auc_score )
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate or [1 - True Negative Rate]')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic example')
    plt.legend(loc="lower right")
    plt.show()

    return None

# %%
fpr, tpr, thresholds = metrics.roc_curve( y_train_pred_final.Converted, y_train_pred_final.Conversion_Prob, drop_intermediate = False )

# %%
# plotting roc curve
draw_roc(y_train_pred_final.Converted, y_train_pred_final.Conversion_Prob)

# %% [markdown]
# ## Making predictions on the test data

# %% [markdown]
# ## scaling

# %%
# scaling the variables
X_test[['TotalVisits', 'Page Views Per Visit', 'Total Time Spent on Website']] = scaler.transform(X_test[['TotalVisits', 'Page Views Per Visit', 'Total Time Spent on Website']])

# %%
X_test = X_test[col]
X_test.head()
# Out:
#       TotalVisits  Total Time Spent on Website  Lead Origin_Lead Add Form  \
# 4771     0.000000                     0.000000                          1
# 6122     0.027888                     0.029049                          0
# 9202     0.015936                     0.416813                          0
# 6570     0.011952                     0.378961                          0
# 2668     0.031873                     0.395246                          0
#
#       Lead Source_Olark Chat  Lead Source_Welingak Website  Do Not Email_Yes  \
# 4771                       0                             0                 0
# 6122                       0                             0                 0
# 9202                       0                             0                 0
# 6570                       0                             0                 1
# 2668                       0                             0                 0
#
# ...

# %%
# addition of constant
X_test_sm = sm.add_constant(X_test[col])

# %%
X_test_sm
# Out:
#       const  TotalVisits  Total Time Spent on Website  \
# 4771    1.0     0.000000                     0.000000
# 6122    1.0     0.027888                     0.029049
# 9202    1.0     0.015936                     0.416813
# 6570    1.0     0.011952                     0.378961
# 2668    1.0     0.031873                     0.395246
# ...     ...          ...                          ...
# 5828    1.0     0.011952                     0.027289
# 6583    1.0     0.011952                     0.152289
# 5531    1.0     0.055777                     0.702025
# 3056    1.0     0.011952                     0.417694
# 4088    1.0     0.019920                     0.530370
#
#       Lead Origin_Lead Add Form  Lead Source_Olark Chat  \
# 4771                          1                       0
# 6122                          0                       0
# 9202                          0                       0
# 6570                          0                       0
# ...

# %%
X_train.columns
# Out:
# Index(['TotalVisits', 'Total Time Spent on Website',
#        'Lead Origin_Lead Add Form', 'Lead Source_Olark Chat',
#        'Lead Source_Welingak Website', 'Do Not Email_Yes',
#        'Last Activity_Had a Phone Conversation', 'Last Activity_SMS Sent',
#        'Specialization_Select', 'What is your current occupation_Student',
#        'What is your current occupation_Unemployed',
#        'Last Notable Activity_Unreachable'],
#       dtype='object')

# %%
X_test.columns
# Out:
# Index(['TotalVisits', 'Total Time Spent on Website',
#        'Lead Origin_Lead Add Form', 'Lead Source_Olark Chat',
#        'Lead Source_Welingak Website', 'Do Not Email_Yes',
#        'Last Activity_Had a Phone Conversation', 'Last Activity_SMS Sent',
#        'Specialization_Select', 'What is your current occupation_Housewife',
#        'What is your current occupation_Student',
#        'What is your current occupation_Unemployed',
#        'What is your current occupation_Working Professional',
#        'Last Notable Activity_Had a Phone Conversation',
#        'Last Notable Activity_Unreachable'],
#       dtype='object')

# %%
X_test.drop(['What is your current occupation_Housewife', 'Last Notable Activity_Had a Phone Conversation',], axis =1, inplace = True)

# %%
X_test.drop(['What is your current occupation_Working Professional'], axis =1, inplace = True)

# %%
y_test_pred = res.predict(sm.add_constant(X_test))

# %%
y_test_pred[:10]
# Out:
# 4771    0.996504
# 6122    0.138112
# 9202    0.718136
# 6570    0.312323
# 2668    0.731056
# 4233    0.822362
# 3368    0.643642
# 9091    0.477191
# 5972    0.301264
# 3631    0.796722
# dtype: float64

# %%
y_pred_1 = pd.DataFrame(y_test_pred)

# %%
y_test_df = pd.DataFrame(y_test)

# %%
y_pred_1.reset_index(drop=True, inplace=True)
y_test_df.reset_index(drop=True, inplace=True)

# %%
y_pred_final = pd.concat([y_test_df, y_pred_1],axis=1)

# %%
y_pred_final= y_pred_final.rename(columns = {0 : 'Conversion_Prob'})

# %%
y_pred_final['final_predicted'] = y_pred_final.Conversion_Prob.map(lambda x: 1 if x > 0.42 else 0)

# %%
metrics.accuracy_score(y_pred_final['Converted'], y_pred_final.final_predicted)
# Out:
# 0.7855648535564853

# %%
confusion2 = metrics.confusion_matrix(y_pred_final['Converted'], y_pred_final.final_predicted )
confusion2
# Out:
# array([[780, 216],
#        [194, 722]], dtype=int64)

# %%
TP = confusion2[1,1] 
TN = confusion2[0,0]
FP = confusion2[0,1]
FN = confusion2[1,0]

# %%
# Specificity
TN / float(TN+FP)
# Out:
# 0.7831325301204819

# %%
# Sensitivity
TP / float(TP+FN)
# Out:
# 0.7882096069868996

# %% [markdown]
# ## Making predictions on test data set

# %%
y_test_pred = res.predict(sm.add_constant(X_test))

# %%
y_test_pred[:10]
# Out:
# 4771    0.996504
# 6122    0.138112
# 9202    0.718136
# 6570    0.312323
# 2668    0.731056
# 4233    0.822362
# 3368    0.643642
# 9091    0.477191
# 5972    0.301264
# 3631    0.796722
# dtype: float64

# %%
y_test_df = pd.DataFrame(y_test)

# %%
y_pred_1.reset_index(drop=True, inplace=True)
y_test_df.reset_index(drop=True, inplace=True)

# %%
y_pred_final = pd.concat([y_test_df, y_pred_1],axis=1)

# %%
y_pred_final= y_pred_final.rename(columns = {0 : 'Conversion_Prob'})

# %%
y_pred_final['final_predicted'] = y_pred_final.Conversion_Prob.map(lambda x: 1 if x > 0.44 else 0)

# %%
metrics.accuracy_score(y_pred_final['Converted'], y_pred_final.final_predicted)
# Out:
# 0.7897489539748954

# %%
confusion2 = metrics.confusion_matrix(y_pred_final['Converted'], y_pred_final.final_predicted )
confusion2
# Out:
# array([[799, 197],
#        [205, 711]], dtype=int64)

# %%
TP = confusion2[1,1]
TN = confusion2[0,0]
FP = confusion2[0,1]
FN = confusion2[1,0]

# %%
# Specificity
TN / float(TN+FP)
# Out:
# 0.8022088353413654

# %%
# Sensitivity
TP / float(TP+FN)
# Out:
# 0.7762008733624454

# %%
# Precision
precision = TP/(TP+FP)
precision
# Out:
# 0.7830396475770925

# %%
# recall
recall = TP/(TP+FN)
recall
# Out:
# 0.7762008733624454
